# %%
spark.sql("""
create table if not exists bronze.sinp_estab_pris (
    sigla       string,
    unidade     string,
    municipio   string,
    endereco    string,
    cep         string,
    uf          string,
    pais        string,
    latitude    double,
    longitude   double
)
stored as parquet
location '/data_lake/bronze/intlpris/sinp_estab_pris'
""")

spark.sql("""
insert overwrite table bronze.sinp_estab_pris values
('APAC' ,'ASSOCIAÇÃO DE PROTEÇÃO E ASSISTÊNCIA AOS CONDENADOS' ,'Vila Velha' ,'Praça Almirante Tamandaré, 193', '29.100-310','ES','Brasil',null,null) ,null ,'ES','Brasil',null,null),
('APACF' ,'ASSOCIAÇÃO PROTEÇÃO E ASSIST CONDENADOS CACH ITAPEMIRIM - CRS MASC' ,null ,null ,null ,'ES','Brasil',null,null),
('CASCUVI' ,'CASA DE CUSTÓDIA DE VIANA' ,'Viana' ,'BR 262 KM 18 5 S N' ,'29130-010' ,'ES','Brasil',null,null),
('CASCUVV' ,'CASA DE CUSTÓDIA DE VILA VELHA' ,'Vila Velha' ,'Rua Mestre Gomes, s/n, Pedra D’Água, Glória' ,'29122-100','ES','Brasil',null,null),
('CDPA' ,'CENTRO DE DETENÇÃO PROVISÓRIA DE ARACRUZ' ,'Aracruz' ,'Estrada Aracruz-Coqueiral, s/n, Fátima' ,'29192-205','ES','Brasil',null,null),
('CDPC' ,'CENTRO DE DETENÇÃO PROVISÓRIA DE CARIACICA' ,'Cariacica' ,null ,null ,'ES','Brasil',null,null),
('CDPCI' ,'CENTRO DE DETENÇÃO PROVISÓRIA DE CACHOEIRO DE ITAPEMIRIM' ,'Cachoeiro de Itapemirim' ,'Rodovia do Governador Lacerda de Aguiar, Km 01, Bairro Coronel Borges' ,'29306-095','ES','Brasil',null,null),
('CDPCOL' ,'CENTRO DE DETENÇÃO PROVISÓRIA DE COLATINA' ,'Colatina' ,'Córrego Santa Fé, s/n' ,'29700-970','ES','Brasil',null,null),
('CDPFV' ,'CENTRO DE DETENÇÃO PROVISÓRIA FEMININO DE VIANA' ,null ,null ,null ,'ES','Brasil',null,null),
('CDPFVV' ,'CENTRO DE DETENÇÃO PROVISÓRIA FEMININO DE VILA VELHA' ,null ,null ,null ,'ES','Brasil',null,null),
('CDPG' ,'CENTRO DE DETENÇÃO PROVISÓRIA DE GUARAPARI' ,'Guarapari' ,'Rodovia do Sol, Contorno Argilino Dario, Km 51,3, Maxinda' ,'29200-970','ES','Brasil',null,null),
('CDPM' ,'CENTRO DE DETENÇÃO PROVISÓRIA DE MARATAÍZES' ,'Marataízes' ,'Rua Espinha de Peixe, s/n, Bairro Acapulco' ,'29345-000','ES','Brasil',null,null),
('CDPS' ,'CENTRO DE DETENÇÃO PROVISÓRIA DA SERRA' ,'Serra' ,'Rodovia do Contorno, BR-101, Km 278, Distrito de Queimados' ,'29160-000','ES','Brasil',null,null),
('CDPSDN' ,'CENTRO DE DETENÇÃO PROVISÓRIA DE SÃO DOMINGOS DO NORTE' ,'São Domingos do Norte' ,'Córrego Braço do Sul, Km 80, s/n' ,'29745-000','ES','Brasil',null,null),
('CDPSM' ,'CENTRO DE DETENÇÃO PROVISÓRIA DE SÃO MATEUS' ,'São Mateus' ,'BR-101 Norte, Km 72,5, Fazenda Rancho das Telhas, Zona Rural' ,'29930-000','ES','Brasil',null,null),
('CDPV II' ,'CENTRO DE DETENÇÃO PROVISÓRIA DE VIANA II' ,'Viana' ,'Rodovia BR-262, Km 18,5' ,'29130-055','ES','Brasil',null,null),
('CDPVV' ,'CENTRO DE DETENÇÃO PROVISÓRIA DE VILA VELHA' ,'Vila Velha' ,'Rodovia BR-101 Sul, Km 313, Fazenda Santa Fé, Xuri' ,'29100-000','ES','Brasil',null,null),
('CDPVV 2' ,'CENTRO DE DETENÇÃO PROVISÓRIA DE VILA VELHA II' ,null ,null ,null ,'ES','Brasil',null,null),
('CPFC' ,'CENTRO PRISIONAL FEMININO DE CARIACICA' ,'Cariacica' ,'Rua Ofelino Meireles, Bairro Bubu' ,'29157-766','ES','Brasil',null,null),
('CPFCI' ,'CENTRO PRISIONAL FEMININO DE CACHOEIRO DE ITAPEMIRIM' ,'Cachoeiro de Itapemirim' ,'Fazenda Monte Líbano, s/n, Zona Rural' ,'29300-970','ES','Brasil',null,null),
('CPFCOL' ,'CENTRO PRISIONAL FEMININO DE COLATINA' ,'Colatina' ,'Córrego Santa Fé, s/n' ,'29700-970','ES','Brasil',null,null),
('CRL' ,'CENTRO DE RESSOCIALIZAÇÃO DE LINHARES' ,'Linhares' ,'Rodovia ES-440, Km 02, Bebedouro' ,'29900-970','ES','Brasil',null,null),
('CTV' ,'CENTRO DE TRIAGEM DE VIANA' ,'Viana' ,'Rodovia BR-262, Km 18,5' ,'29130-055','ES','Brasil',null,null),
('DIMCME' ,'DIMCME - SERVIÇO PENAL' ,null ,null ,null ,'ES','Brasil',null,null),
('EPEN' ,'ESCOLA PENITENCIÁRIA' ,null ,null ,null ,'ES','Brasil',null,null),
('HCTP' ,'HOSPITAL DE CUSTÓDIA E TRATAMENTO PSIQUIÁTRICO' ,null ,null ,null ,'ES','Brasil',null,null),
('IRS' ,'INSTITUTO DE READAPTAÇÃO SOCIAL' ,null ,null ,null ,'ES','Brasil',null,null),
('PAES' ,'PENITENCIÁRIA AGRÍCOLA DO ESPÍRITO SANTO' ,'Viana' ,'Rodovia BR-262, Km 18,5' ,'29130-055','ES','Brasil',null,null),
('PEF' ,'PENITENCIÁRIA ESTADUAL FEMININA' ,null ,null ,null ,'ES','Brasil',null,null),
('PSMA II' ,'PENITENCIÁRIA DE SEGURANÇA MÁXIMA II' ,'Viana' ,'Rodovia BR-262, Km 18,5' ,'29130-055','ES','Brasil',null,null),
('PSMCOL' ,'PENITENCIÁRIA SEMIABERTA MASCULINA DE COLATINA' ,'Colatina' ,'Avenida das Nações, s/n, Bairro Benjamin Carlos dos Santos (IBC)' ,'29712-408','ES','Brasil',null,null),
('PSME I' ,'PENITENCIÁRIA DE SEGURANÇA MÉDIA I' ,'Viana' ,'Rodovia BR-262, Km 18,5' ,'29130-055','ES','Brasil',null,null),
('PSME II' ,'PENITENCIÁRIA DE SEGURANÇA MÉDIA II' ,'Viana' ,'Rodovia BR-262, Km 18,5' ,'29130-055','ES','Brasil',null,null),
('PSMECOL' ,'PENITENCIÁRIA DE SEGURANÇA MÉDIA DE COLATINA' ,'Colatina' ,'Córrego Santa Fé, s/n' ,'29700-970','ES','Brasil',null,null),
('PSSM' ,'PENITENCIÁRIA SEMIABERTA DE SÃO MATEUS' ,'São Mateus' ,'Rodovia Governador Mario Covas, BR-101 Norte, Km 72,5, s/n, Rio Preto da Rodovia','29940-800','ES','Brasil',null,null),
('PSVV' ,'PENITENCIÁRIA SEMIABERTA DE VILA VELHA' ,'Vila Velha' ,'Rodovia BR-101 Sul, Km 313, Fazenda Santa Fé, Xuri' ,'29100-000','ES','Brasil',null,null),
('PSVV II' ,'PENITENCIÁRIA SEMIABERTA DE VILA VELHA II' ,null ,null ,null ,'ES','Brasil',null,null),
('QCGPMES' ,'QUARTEL DO COMANDO GERAL DA POLÍCIA MILITAR DO EST. DO ESPÍRITO SANTO' ,'Vitória' ,null ,null ,'ES','Brasil',null,null),
('UCTP' ,'UNIDADE DE CUSTÓDIA E TRATAMENTO PSIQUIÁTRICO' ,'Cariacica' ,'Av. José Sette, s/n, Bairro Roças Velhas' ,'29156-970','ES','Brasil',null,null),
('USP' ,'UNIDADE DE SAÚDE PRISIONAL' ,'Viana' ,'Rodovia BR-262, Km 18,5' ,'29130-055','ES','Brasil',null,null)
""")
# Out:
# DataFrame[]

# %%
a=spark.sql("""
Select * from bronze.LIVROS_ACESSO_UNIDADE_PROFISSIONAISUNIDADE;
""")

a.show(50,False)
# Out:
# +---+------------+----------+---------+-----------------------------------------------------------------+-------+-------+-----+-----------------------------------------------+--------------------------+---------+-----------+-----------------+
# |id |profissoes  |hr_entrada|hr_saida |nome                                                             |infopen|galeria|cela |motivo                                         |data_registro             |equipe_id|presidio_id|nome_profissional|
# +---+------------+----------+---------+-----------------------------------------------------------------+-------+-------+-----+-----------------------------------------------+--------------------------+---------+-----------+-----------------+
# |1  |LABORAL     |8HS30MIN  |9HS00MIN |Roberto Luiz Ferreira                                            |3456789|D      |5    |teste                                          |2024-09-03 19:12:33.38747 |1        |2          |1                |
# ...
