# %%
import sys
import importlib

sys.path.append("/home/diogo.silva/sejus-sinp/00_ETL/Modular")

import etapa_00_orquestrador as orch
importlib.reload(orch)

orch.executar_todas()
# Out:
# Traceback (most recent call last):
#
#   File "/opt/cloudera/jupyterhub/lib64/python3.6/site-packages/IPython/core/interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-1-69ab44c8d44c>", line 6, in <module>
#     import etapa_00_orquestrador as orch
#
#   File "/home/diogo.silva/sejus-sinp/00_ETL/Modular/etapa_00_orquestrador.py", line 5, in <module>
#     from contexto import spark, path
#
#   File "/home/diogo.silva/sejus-sinp/00_ETL/Modular/contexto.py", line 122
#     else:
#        ^
# IndentationError: expected an indented block
