# %%
import sys
import importlib

sys.path.append("/home/diogo.silva/sejus-sinp/00_ETL/Modular")

import etapa_00_orquestrador as orch
importlib.reload(orch)

orch.executar_todas()
# Out:
# /opt/cloudera/jupyterhub/lib64/python3.6/site-packages/requests/__init__.py:104: RequestsDependencyWarning: urllib3 (1.26.12) or chardet (5.0.0)/charset_normalizer (2.0.12) doesn't match a supported version!
#   RequestsDependencyWarning)
# ...
# [ORQUESTRADOR][INICIO] 2026-05-29 16:46:22
# ...
# ----------------------------------------------------------------------------------------------------
# [INICIO] 01_ent_pessoa | 2026-05-29 16:46:22
# [POSTGRES] sinp.sinp_ent_pessoa | linhas=282025 | particoes=4
# [POSTGRES] sinp.sinp_ent_pessoa_outras | linhas=475 | particoes=2
# [POSTGRES] sinp.sinp_pnt_pessoa_preso | linhas=114687 | particoes=4
# [FIM] 01_ent_pessoa | 2026-05-29 16:55:28 | DURAÇÃO: 00:09:06
# ----------------------------------------------------------------------------------------------------
# [INICIO] 02_localizacao_cela | 2026-05-29 16:55:28
# [POSTGRES] sinp.sinp_ent_estabelecimento | linhas=54 | particoes=2
# [POSTGRES] sinp.sinp_ent_galeria | linhas=38 | particoes=2
# ...
