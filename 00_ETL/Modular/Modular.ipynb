# %%
import sys
import importlib

sys.path.append("/home/diogo.silva/sejus-sinp/00_ETL/Modular")

import etapa_00_orquestrador as orch
importlib.reload(orch)

orch.executar_todas()
# Out:
# /opt/cloudera/jupyterhub/lib64/python3.6/site-packages/requests/__init__.py:104: RequestsDependencyWarning: urllib3 (1.26.12) or chardet (5.0.0)/charset_normalizer (2.0.12) doesn't match a supported version!
#   RequestsDependencyWarning)
# [INICIO] 01_ent_pessoa
# CREATE EXTERNAL TABLE gold.sinp_ent_pes_p1
#                         (id_preso char(6),
#     id_pessoa varchar(24),
#     origem char(11),
#     cod_documento_referencia integer,
#     desc_documento_referencia varchar(27),
#     documento varchar(20),
#     nome_pessoa varchar(99),
#     sexo_pessoa char(1),
#     flag_presidiario integer,
#     flag_advogado integer,
#     flag_servidor integer,
#     flag_visitante integer,
#     flag_ocorrencia_10d integer,
#     flag_ocorrencia_30d integer,
#     flag_ocorrencia_60d integer,
#     data_nascimento_pessoa date,
#     data_ultima_prisao date,
#     nome_mae varchar(90),
#     nome_pai varchar(98),
#     etnia char(9),
#     estado_civil char(15),
#     escolaridade varchar(39),
#     profissao varchar(103),
#     religiao char(15),
#     flag_tem_filhos integer,
#     quantidade_filhos char(14),
#     naturalidade_municipio varchar(31),
#     naturalidade_uf char(2),
#     pais_origem_estrangeiro char(2),
#     cidade_origem_estrangeiro varchar(21),
#     necessidade_especial char(1),
#     flag_sabe_ler integer,
#     flag_sabe_escrever integer,
#     flag_recebe_visita integer,
#     flag_relacao_conjugal integer)
#                         STORED AS PARQUET LOCATION '/data_lake/gold/intlpris/sinp_ent_pes_p1'
#
# DROP TABLE gold.sinp_ent_pes_p1
# Estatísticas atualizadas para gold.sinp_ent_pes_p1
# CREATE EXTERNAL TABLE gold.tmp_base_siarhes
#                         (cpf_normalizado char(11),
#     nome_pessoa varchar(49),
#     rg char(15),
#     dt_extracao varchar(23),
#     numero_funcional char(12),
#     cargo varchar(61),
#     categoria varchar(20),
#     subcategoria varchar(20),
#     situacao char(8),
#     tipo_vinculo varchar(19),
#     subempresa varchar(47),
#     rn integer)
#                         STORED AS PARQUET LOCATION '/data_lake/gold/intlpris/tmp_base_siarhes'
#
# DROP TABLE gold.tmp_base_siarhes
# Estatísticas atualizadas para gold.tmp_base_siarhes
# CREATE EXTERNAL TABLE gold.tmp_filtrada_siarhes
#                         (cpf_normalizado char(11),
#     cpf_formatado char(14),
#     nome_pessoa varchar(49),
#     rg char(15),
#     dt_extracao varchar(23),
#     numero_funcional char(12),
#     cargo varchar(61),
#     categoria varchar(20),
#     subcategoria varchar(20),
#     situacao char(8),
#     tipo_vinculo varchar(19),
#     subempresa varchar(47))
#                         STORED AS PARQUET LOCATION '/data_lake/gold/intlpris/tmp_filtrada_siarhes'
#
# DROP TABLE gold.tmp_filtrada_siarhes
# Estatísticas atualizadas para gold.tmp_filtrada_siarhes
# CREATE EXTERNAL TABLE gold.tmp_base_pessoa_atual
#                         (id_preso char(6),
#     id_pessoa varchar(24),
#     origem char(11),
#     cod_documento_referencia integer,
#     desc_documento_referencia varchar(27),
#     documento varchar(20),
#     nome_pessoa varchar(99),
#     sexo_pessoa char(1),
#     flag_presidiario integer,
#     flag_advogado integer,
#     flag_servidor integer,
#     flag_visitante integer,
#     flag_ocorrencia_10d integer,
#     flag_ocorrencia_30d integer,
#     flag_ocorrencia_60d integer,
#     data_nascimento_pessoa date,
#     data_ultima_prisao date,
#     nome_mae varchar(90),
#     nome_pai varchar(98),
#     etnia char(9),
#     estado_civil char(15),
#     escolaridade varchar(39),
#     profissao varchar(103),
#     religiao char(15),
#     flag_tem_filhos integer,
#     quantidade_filhos char(14),
#     naturalidade_municipio varchar(31),
#     naturalidade_uf char(2),
#     pais_origem_estrangeiro char(2),
#     cidade_origem_estrangeiro varchar(21),
#     necessidade_especial char(1),
#     flag_sabe_ler integer,
#     flag_sabe_escrever integer,
#     flag_recebe_visita integer,
#     flag_relacao_conjugal integer,
#     cpf_normalizado char(11))
#                         STORED AS PARQUET LOCATION '/data_lake/gold/intlpris/tmp_base_pessoa_atual'
#
# DROP TABLE gold.tmp_base_pessoa_atual
# Estatísticas atualizadas para gold.tmp_base_pessoa_atual
# CREATE EXTERNAL TABLE gold.tmp_pessoa_atualizada_servidor
#                         (id_preso char(6),
#     id_pessoa char(15),
#     origem char(8),
#     cod_documento_referencia integer,
#     desc_documento_referencia char(3),
#     documento char(14),
#     nome_pessoa varchar(35),
#     sexo_pessoa char(1),
#     flag_presidiario integer,
#     flag_advogado integer,
#     flag_servidor integer,
#     flag_visitante integer,
#     flag_ocorrencia_10d integer,
#     flag_ocorrencia_30d integer,
#     flag_ocorrencia_60d integer,
#     data_nascimento_pessoa date,
#     data_ultima_prisao date,
#     nome_mae varchar(40),
#     nome_pai varchar(33),
#     etnia char(7))
#                         STORED AS PARQUET LOCATION '/data_lake/gold/intlpris/tmp_pessoa_atualizada_servidor'
#
# DROP TABLE gold.tmp_pessoa_atualizada_servidor
# Estatísticas atualizadas para gold.tmp_pessoa_atualizada_servidor
# CREATE EXTERNAL TABLE gold.tmp_pessoa_mantida
#                         (id_preso char(6),
#     id_pessoa varchar(24),
#     origem char(11),
#     cod_documento_referencia integer,
#     desc_documento_referencia varchar(27),
#     documento varchar(20),
#     nome_pessoa varchar(99),
#     sexo_pessoa char(1),
#     flag_presidiario integer,
#     flag_advogado integer,
#     flag_servidor integer,
#     flag_visitante integer,
#     flag_ocorrencia_10d integer,
#     flag_ocorrencia_30d integer,
#     flag_ocorrencia_60d integer,
#     data_nascimento_pessoa date,
#     data_ultima_prisao date,
#     nome_mae varchar(90),
#     nome_pai varchar(98),
#     etnia char(9))
#                         STORED AS PARQUET LOCATION '/data_lake/gold/intlpris/tmp_pessoa_mantida'
#
# DROP TABLE gold.tmp_pessoa_mantida
# Estatísticas atualizadas para gold.tmp_pessoa_mantida
# CREATE EXTERNAL TABLE gold.tmp_pessoa_nova_servidor
#                         (id_preso char(1),
#     id_pessoa char(15),
#     origem char(8),
#     cod_documento_referencia integer,
#     desc_documento_referencia char(3),
#     documento char(14),
#     nome_pessoa varchar(49),
#     sexo_pessoa char(1),
#     flag_presidiario integer,
#     flag_advogado integer,
#     flag_servidor integer,
#     flag_visitante integer,
#     flag_ocorrencia_10d integer,
#     flag_ocorrencia_30d integer,
#     flag_ocorrencia_60d integer,
#     data_nascimento_pessoa date,
#     data_ultima_prisao date,
#     nome_mae char(1),
#     nome_pai char(1),
#     etnia char(1))
#                         STORED AS PARQUET LOCATION '/data_lake/gold/intlpris/tmp_pessoa_nova_servidor'
#
# DROP TABLE gold.tmp_pessoa_nova_servidor
# Estatísticas atualizadas para gold.tmp_pessoa_nova_servidor
# CREATE EXTERNAL TABLE gold.sinp_ent_pessoa_shiares
#                         (id_preso char(6),
#     id_pessoa varchar(24),
#     origem char(11),
#     cod_documento_referencia integer,
#     desc_documento_referencia varchar(27),
#     documento varchar(20),
#     nome_pessoa varchar(99),
#     sexo_pessoa char(1),
#     flag_presidiario integer,
#     flag_advogado integer,
#     flag_servidor integer,
#     flag_visitante integer,
#     flag_ocorrencia_10d integer,
#     flag_ocorrencia_30d integer,
#     flag_ocorrencia_60d integer,
#     data_nascimento_pessoa date,
#     data_ultima_prisao date,
#     nome_mae varchar(90),
#     nome_pai varchar(98),
#     etnia char(9))
#                         STORED AS PARQUET LOCATION '/data_lake/gold/intlpris/sinp_ent_pessoa_shiares'
#
# DROP TABLE gold.sinp_ent_pessoa_shiares
# Estatísticas atualizadas para gold.sinp_ent_pessoa_shiares
# CREATE EXTERNAL TABLE gold.tmp_base_cavi
#                         (itemnum char(6),
#     numeroonbase char(12),
#     statussolicitacao char(13),
#     resultanalise varchar(22),
#     telcelular char(11),
#     nome_pessoa varchar(58),
#     emailinteressado varchar(44),
#     cpf_normalizado char(11),
#     telresidencial char(10),
#     rg char(11),
#     orgaoemissor char(12),
#     estadoemissor char(2),
#     sexo_pessoa varchar(21),
#     profissao varchar(51),
#     cpf_detento_normalizado char(11),
#     nome_detento varchar(69),
#     rg_detento char(11),
#     nome_mae_detento varchar(82),
#     tipovisita varchar(23),
#     vinculodetento varchar(20),
#     grauparentesco char(14),
#     ctprocesso varchar(20),
#     ctfilaatual varchar(33),
#     ctfilaorigem varchar(33),
#     setorresponsavel varchar(25),
#     unidadeprisional varchar(59))
#                         STORED AS PARQUET LOCATION '/data_lake/gold/intlpris/tmp_base_cavi'
#
# DROP TABLE gold.tmp_base_cavi
# Estatísticas atualizadas para gold.tmp_base_cavi
# CREATE EXTERNAL TABLE gold.tmp_base_cavi_rank
#                         (itemnum char(6),
#     numeroonbase char(12),
#     statussolicitacao char(13),
#     resultanalise varchar(22),
#     telcelular char(11),
#     nome_pessoa varchar(58),
#     emailinteressado varchar(44),
#     cpf_normalizado char(11),
#     telresidencial char(10),
#     rg char(11),
#     orgaoemissor char(12),
#     estadoemissor char(2),
#     sexo_pessoa varchar(21),
#     profissao varchar(51),
#     cpf_detento_normalizado char(11),
#     nome_detento varchar(69),
#     rg_detento char(11),
#     nome_mae_detento varchar(82),
#     tipovisita varchar(23),
#     vinculodetento varchar(20),
#     grauparentesco char(14),
#     ctprocesso varchar(20),
#     ctfilaatual varchar(33),
#     ctfilaorigem varchar(33),
#     setorresponsavel varchar(25),
#     unidadeprisional varchar(59),
#     rn integer)
#                         STORED AS PARQUET LOCATION '/data_lake/gold/intlpris/tmp_base_cavi_rank'
#
# DROP TABLE gold.tmp_base_cavi_rank
# Estatísticas atualizadas para gold.tmp_base_cavi_rank
# CREATE EXTERNAL TABLE gold.tmp_filtrada_cavi
#                         (cpf_normalizado char(11),
#     cpf_formatado char(14),
#     nome_pessoa varchar(58),
#     rg char(11),
#     sexo_pessoa varchar(21),
#     orgaoemissor char(12),
#     estadoemissor char(2),
#     profissao varchar(51),
#     telcelular char(11),
#     telresidencial char(10),
#     emailinteressado varchar(44),
#     itemnum char(6),
#     numeroonbase char(12),
#     statussolicitacao char(13),
#     resultanalise varchar(22),
#     tipovisita varchar(23),
#     vinculodetento varchar(20),
#     grauparentesco char(14),
#     unidadeprisional varchar(59))
#                         STORED AS PARQUET LOCATION '/data_lake/gold/intlpris/tmp_filtrada_cavi'
#
# DROP TABLE gold.tmp_filtrada_cavi
# Estatísticas atualizadas para gold.tmp_filtrada_cavi
# CREATE EXTERNAL TABLE gold.tmp_base_pessoa_atual_cavi
#                         (id_preso char(6),
#     id_pessoa varchar(24),
#     origem char(11),
#     cod_documento_referencia integer,
#     desc_documento_referencia varchar(27),
#     documento varchar(20),
#     nome_pessoa varchar(99),
#     sexo_pessoa char(1),
#     flag_presidiario integer,
#     flag_advogado integer,
#     flag_servidor integer,
#     flag_visitante integer,
#     flag_ocorrencia_10d integer,
#     flag_ocorrencia_30d integer,
#     flag_ocorrencia_60d integer,
#     data_nascimento_pessoa date,
#     data_ultima_prisao date,
#     nome_mae varchar(90),
#     nome_pai varchar(98),
#     etnia char(9),
#     cpf_normalizado char(11))
#                         STORED AS PARQUET LOCATION '/data_lake/gold/intlpris/tmp_base_pessoa_atual_cavi'
#
# DROP TABLE gold.tmp_base_pessoa_atual_cavi
# Estatísticas atualizadas para gold.tmp_base_pessoa_atual_cavi
# CREATE EXTERNAL TABLE gold.tmp_pessoa_atualizada_visitante
#                         (id_preso char(6),
#     id_pessoa char(15),
#     origem char(8),
#     cod_documento_referencia integer,
#     desc_documento_referencia char(3),
#     documento char(14),
#     nome_pessoa varchar(39),
#     sexo_pessoa char(9),
#     flag_presidiario integer,
#     flag_advogado integer,
#     flag_servidor integer,
#     flag_visitante integer,
#     flag_ocorrencia_10d integer,
#     flag_ocorrencia_30d integer,
#     flag_ocorrencia_60d integer,
#     data_nascimento_pessoa date,
#     data_ultima_prisao date,
#     nome_mae varchar(41),
#     nome_pai varchar(37),
#     etnia char(7))
#                         STORED AS PARQUET LOCATION '/data_lake/gold/intlpris/tmp_pessoa_atualizada_visitante'
#
# DROP TABLE gold.tmp_pessoa_atualizada_visitante
# Estatísticas atualizadas para gold.tmp_pessoa_atualizada_visitante
# CREATE EXTERNAL TABLE gold.tmp_pessoa_mantida_visitante
#                         (id_preso char(6),
#     id_pessoa varchar(24),
#     origem char(11),
#     cod_documento_referencia integer,
#     desc_documento_referencia varchar(27),
#     documento varchar(20),
#     nome_pessoa varchar(99),
#     sexo_pessoa char(1),
#     flag_presidiario integer,
#     flag_advogado integer,
#     flag_servidor integer,
#     flag_visitante integer,
#     flag_ocorrencia_10d integer,
#     flag_ocorrencia_30d integer,
#     flag_ocorrencia_60d integer,
#     data_nascimento_pessoa date,
#     data_ultima_prisao date,
#     nome_mae varchar(90),
#     nome_pai varchar(98),
#     etnia char(9))
#                         STORED AS PARQUET LOCATION '/data_lake/gold/intlpris/tmp_pessoa_mantida_visitante'
#
# DROP TABLE gold.tmp_pessoa_mantida_visitante
# Estatísticas atualizadas para gold.tmp_pessoa_mantida_visitante
# CREATE EXTERNAL TABLE gold.tmp_pessoa_nova_visitante
#                         (id_preso char(1),
#     id_pessoa char(15),
#     origem char(9),
#     cod_documento_referencia integer,
#     desc_documento_referencia char(3),
#     documento char(14),
#     nome_pessoa varchar(58),
#     sexo_pessoa varchar(21),
#     flag_presidiario integer,
#     flag_advogado integer,
#     flag_servidor integer,
#     flag_visitante integer,
#     flag_ocorrencia_10d integer,
#     flag_ocorrencia_30d integer,
#     flag_ocorrencia_60d integer,
#     data_nascimento_pessoa date,
#     data_ultima_prisao date,
#     nome_mae char(1),
#     nome_pai char(1),
#     etnia char(1))
#                         STORED AS PARQUET LOCATION '/data_lake/gold/intlpris/tmp_pessoa_nova_visitante'
#
# DROP TABLE gold.tmp_pessoa_nova_visitante
# Estatísticas atualizadas para gold.tmp_pessoa_nova_visitante
# CREATE EXTERNAL TABLE gold.df_pessoa_nova_visitante
#                         (id_preso char(6),
#     id_pessoa varchar(24),
#     origem char(11),
#     cod_documento_referencia integer,
#     desc_documento_referencia varchar(27),
#     documento varchar(20),
#     nome_pessoa varchar(99),
#     sexo_pessoa varchar(21),
#     flag_presidiario integer,
#     flag_advogado integer,
#     flag_servidor integer,
#     flag_visitante integer,
#     flag_ocorrencia_10d integer,
#     flag_ocorrencia_30d integer,
#     flag_ocorrencia_60d integer,
#     data_nascimento_pessoa date,
#     data_ultima_prisao date,
#     nome_mae varchar(90),
#     nome_pai varchar(98),
#     etnia char(9))
#                         STORED AS PARQUET LOCATION '/data_lake/gold/intlpris/df_pessoa_nova_visitante'
#
# DROP TABLE gold.df_pessoa_nova_visitante
# Estatísticas atualizadas para gold.df_pessoa_nova_visitante
# CREATE EXTERNAL TABLE gold.tmp_base_advogado
#                         (id_advogado_origem char(4),
#     nome_pessoa varchar(53),
#     estado_oab char(2),
#     oab_bruta char(8),
#     oab_normalizada char(8),
#     id_pessoa char(13),
#     documento_oab char(9),
#     rn integer)
#                         STORED AS PARQUET LOCATION '/data_lake/gold/intlpris/tmp_base_advogado'
#
# DROP TABLE gold.tmp_base_advogado
# Estatísticas atualizadas para gold.tmp_base_advogado
# CREATE EXTERNAL TABLE gold.tmp_filtrada_advogado
#                         (id_advogado_origem char(4),
#     id_pessoa char(13),
#     nome_pessoa varchar(53),
#     estado_oab char(2),
#     oab_bruta char(8),
#     oab_normalizada char(8),
#     documento_oab char(9))
#                         STORED AS PARQUET LOCATION '/data_lake/gold/intlpris/tmp_filtrada_advogado'
#
# DROP TABLE gold.tmp_filtrada_advogado
# Estatísticas atualizadas para gold.tmp_filtrada_advogado
# CREATE EXTERNAL TABLE gold.tmp_base_pessoa_atual_advogado
#                         (id_preso char(6),
#     id_pessoa varchar(24),
#     origem char(11),
#     cod_documento_referencia integer,
#     desc_documento_referencia varchar(27),
#     documento varchar(20),
#     nome_pessoa varchar(99),
#     sexo_pessoa varchar(21),
#     flag_presidiario integer,
#     flag_advogado integer,
#     flag_servidor integer,
#     flag_visitante integer,
#     flag_ocorrencia_10d integer,
#     flag_ocorrencia_30d integer,
#     flag_ocorrencia_60d integer,
#     data_nascimento_pessoa date,
#     data_ultima_prisao date,
#     nome_mae varchar(90),
#     nome_pai varchar(98),
#     etnia char(9),
#     id_pessoa_advogado char(1))
#                         STORED AS PARQUET LOCATION '/data_lake/gold/intlpris/tmp_base_pessoa_atual_advogado'
#
# DROP TABLE gold.tmp_base_pessoa_atual_advogado
# Estatísticas atualizadas para gold.tmp_base_pessoa_atual_advogado
# CREATE EXTERNAL TABLE gold.tmp_pessoa_atualizada_advogado
#                         (id_preso char(1),
#     id_pessoa char(1),
#     origem char(1),
#     cod_documento_referencia integer,
#     desc_documento_referencia char(1),
#     documento char(1),
#     nome_pessoa char(1),
#     sexo_pessoa char(1),
#     flag_presidiario integer,
#     flag_advogado integer,
#     flag_servidor integer,
#     flag_visitante integer,
#     flag_ocorrencia_10d integer,
#     flag_ocorrencia_30d integer,
#     flag_ocorrencia_60d integer,
#     data_nascimento_pessoa date,
#     data_ultima_prisao date,
#     nome_mae char(1),
#     nome_pai char(1),
#     etnia char(1))
#                         STORED AS PARQUET LOCATION '/data_lake/gold/intlpris/tmp_pessoa_atualizada_advogado'
#
# DROP TABLE gold.tmp_pessoa_atualizada_advogado
# Estatísticas atualizadas para gold.tmp_pessoa_atualizada_advogado
# CREATE EXTERNAL TABLE gold.tmp_pessoa_mantida_advogado
#                         (id_preso char(6),
#     id_pessoa varchar(24),
#     origem char(11),
#     cod_documento_referencia integer,
#     desc_documento_referencia varchar(27),
#     documento varchar(20),
#     nome_pessoa varchar(99),
#     sexo_pessoa varchar(21),
#     flag_presidiario integer,
#     flag_advogado integer,
#     flag_servidor integer,
#     flag_visitante integer,
#     flag_ocorrencia_10d integer,
#     flag_ocorrencia_30d integer,
#     flag_ocorrencia_60d integer,
#     data_nascimento_pessoa date,
#     data_ultima_prisao date,
#     nome_mae varchar(90),
#     nome_pai varchar(98),
#     etnia char(9))
#                         STORED AS PARQUET LOCATION '/data_lake/gold/intlpris/tmp_pessoa_mantida_advogado'
#
# DROP TABLE gold.tmp_pessoa_mantida_advogado
# Estatísticas atualizadas para gold.tmp_pessoa_mantida_advogado
# CREATE EXTERNAL TABLE gold.tmp_pessoa_nova_advogado
#                         (id_preso char(1),
#     id_pessoa char(13),
#     origem char(8),
#     cod_documento_referencia integer,
#     desc_documento_referencia char(3),
#     documento char(9),
#     nome_pessoa varchar(53),
#     sexo_pessoa char(1),
#     flag_presidiario integer,
#     flag_advogado integer,
#     flag_servidor integer,
#     flag_visitante integer,
#     flag_ocorrencia_10d integer,
#     flag_ocorrencia_30d integer,
#     flag_ocorrencia_60d integer,
#     data_nascimento_pessoa date,
#     data_ultima_prisao date,
#     nome_mae char(1),
#     nome_pai char(1),
#     etnia char(1))
#                         STORED AS PARQUET LOCATION '/data_lake/gold/intlpris/tmp_pessoa_nova_advogado'
#
# DROP TABLE gold.tmp_pessoa_nova_advogado
# Estatísticas atualizadas para gold.tmp_pessoa_nova_advogado
# CREATE EXTERNAL TABLE gold.df_pessoa_final_advogado
#                         (id_preso char(6),
#     id_pessoa varchar(24),
#     origem char(11),
#     cod_documento_referencia integer,
#     desc_documento_referencia varchar(27),
#     documento varchar(20),
#     nome_pessoa varchar(99),
#     sexo_pessoa varchar(21),
#     flag_presidiario integer,
#     flag_advogado integer,
#     flag_servidor integer,
#     flag_visitante integer,
#     flag_ocorrencia_10d integer,
#     flag_ocorrencia_30d integer,
#     flag_ocorrencia_60d integer,
#     data_nascimento_pessoa date,
#     data_ultima_prisao date,
#     nome_mae varchar(90),
#     nome_pai varchar(98),
#     etnia char(9))
#                         STORED AS PARQUET LOCATION '/data_lake/gold/intlpris/df_pessoa_final_advogado'
#
# DROP TABLE gold.df_pessoa_final_advogado
# Estatísticas atualizadas para gold.df_pessoa_final_advogado
# CREATE EXTERNAL TABLE gold.tmp_base_visitafamiliar
#                         (id_vinculo_origem char(6),
#     nome_pessoa varchar(86),
#     documento_original char(11),
#     telefone char(15),
#     cpf_normalizado char(11),
#     documento_normalizado char(11),
#     chave_documento char(15))
#                         STORED AS PARQUET LOCATION '/data_lake/gold/intlpris/tmp_base_visitafamiliar'
#
# DROP TABLE gold.tmp_base_visitafamiliar
# Estatísticas atualizadas para gold.tmp_base_visitafamiliar
# CREATE EXTERNAL TABLE gold.tmp_base_visitafamiliar_rank
#                         (id_vinculo_origem char(6),
#     nome_pessoa varchar(86),
#     documento_original char(11),
#     telefone char(15),
#     cpf_normalizado char(11),
#     documento_normalizado char(11),
#     chave_documento char(15),
#     rn integer)
#                         STORED AS PARQUET LOCATION '/data_lake/gold/intlpris/tmp_base_visitafamiliar_rank'
#
# DROP TABLE gold.tmp_base_visitafamiliar_rank
# Estatísticas atualizadas para gold.tmp_base_visitafamiliar_rank
# CREATE EXTERNAL TABLE gold.tmp_filtrada_visitafamiliar
#                         (id_vinculo_origem char(6),
#     nome_pessoa varchar(86),
#     documento_original char(11),
#     telefone char(15),
#     cpf_normalizado char(11),
#     documento_normalizado char(11),
#     chave_documento char(15),
#     documento_formatado char(14),
#     cod_documento_referencia integer,
#     desc_documento_referencia char(9))
#                         STORED AS PARQUET LOCATION '/data_lake/gold/intlpris/tmp_filtrada_visitafamiliar'
#
# DROP TABLE gold.tmp_filtrada_visitafamiliar
# Estatísticas atualizadas para gold.tmp_filtrada_visitafamiliar
# CREATE EXTERNAL TABLE gold.tmp_base_pessoa_atual_familiar
#                         (id_preso char(6),
#     id_pessoa varchar(24),
#     origem char(11),
#     cod_documento_referencia integer,
#     desc_documento_referencia varchar(27),
#     documento varchar(20),
#     nome_pessoa varchar(99),
#     sexo_pessoa varchar(21),
#     flag_presidiario integer,
#     flag_advogado integer,
#     flag_servidor integer,
#     flag_visitante integer,
#     flag_ocorrencia_10d integer,
#     flag_ocorrencia_30d integer,
#     flag_ocorrencia_60d integer,
#     data_nascimento_pessoa date,
#     data_ultima_prisao date,
#     nome_mae varchar(90),
#     nome_pai varchar(98),
#     etnia char(9),
#     chave_documento varchar(24))
#                         STORED AS PARQUET LOCATION '/data_lake/gold/intlpris/tmp_base_pessoa_atual_familiar'
#
# DROP TABLE gold.tmp_base_pessoa_atual_familiar
# Estatísticas atualizadas para gold.tmp_base_pessoa_atual_familiar
# CREATE EXTERNAL TABLE gold.tmp_pessoa_atualizada_familiar
#                         (id_preso char(6),
#     id_pessoa varchar(20),
#     origem char(9),
#     cod_documento_referencia integer,
#     desc_documento_referencia char(3),
#     documento char(14),
#     nome_pessoa varchar(75),
#     sexo_pessoa varchar(21),
#     flag_presidiario integer,
#     flag_advogado integer,
#     flag_servidor integer,
#     flag_visitante integer,
#     flag_ocorrencia_10d integer,
#     flag_ocorrencia_30d integer,
#     flag_ocorrencia_60d integer,
#     data_nascimento_pessoa date,
#     data_ultima_prisao date,
#     nome_mae varchar(44),
#     nome_pai varchar(43),
#     etnia char(9))
#                         STORED AS PARQUET LOCATION '/data_lake/gold/intlpris/tmp_pessoa_atualizada_familiar'
#
# DROP TABLE gold.tmp_pessoa_atualizada_familiar
# Estatísticas atualizadas para gold.tmp_pessoa_atualizada_familiar
# CREATE EXTERNAL TABLE gold.tmp_pessoa_mantida_familiar
#                         (id_preso char(6),
#     id_pessoa varchar(24),
#     origem char(11),
#     cod_documento_referencia integer,
#     desc_documento_referencia varchar(27),
#     documento varchar(20),
#     nome_pessoa varchar(99),
#     sexo_pessoa char(9),
#     flag_presidiario integer,
#     flag_advogado integer,
#     flag_servidor integer,
#     flag_visitante integer,
#     flag_ocorrencia_10d integer,
#     flag_ocorrencia_30d integer,
#     flag_ocorrencia_60d integer,
#     data_nascimento_pessoa date,
#     data_ultima_prisao date,
#     nome_mae varchar(90),
#     nome_pai varchar(98),
#     etnia char(9))
#                         STORED AS PARQUET LOCATION '/data_lake/gold/intlpris/tmp_pessoa_mantida_familiar'
#
# DROP TABLE gold.tmp_pessoa_mantida_familiar
# Estatísticas atualizadas para gold.tmp_pessoa_mantida_familiar
# CREATE EXTERNAL TABLE gold.tmp_pessoa_nova_familiar
#                         (id_preso char(1),
#     id_pessoa char(15),
#     origem char(15),
#     cod_documento_referencia integer,
#     desc_documento_referencia char(9),
#     documento char(14),
#     nome_pessoa varchar(86),
#     sexo_pessoa char(1),
#     flag_presidiario integer,
#     flag_advogado integer,
#     flag_servidor integer,
#     flag_visitante integer,
#     flag_ocorrencia_10d integer,
#     flag_ocorrencia_30d integer,
#     flag_ocorrencia_60d integer,
#     data_nascimento_pessoa date,
#     data_ultima_prisao date,
#     nome_mae char(1),
#     nome_pai char(1),
#     etnia char(1))
#                         STORED AS PARQUET LOCATION '/data_lake/gold/intlpris/tmp_pessoa_nova_familiar'
#
# DROP TABLE gold.tmp_pessoa_nova_familiar
# Estatísticas atualizadas para gold.tmp_pessoa_nova_familiar
# CREATE EXTERNAL TABLE gold.df_pessoa_final_familiar
#                         (id_preso char(6),
#     id_pessoa varchar(24),
#     origem char(15),
#     cod_documento_referencia integer,
#     desc_documento_referencia varchar(27),
#     documento varchar(20),
#     nome_pessoa varchar(99),
#     sexo_pessoa varchar(21),
#     flag_presidiario integer,
#     flag_advogado integer,
#     flag_servidor integer,
#     flag_visitante integer,
#     flag_ocorrencia_10d integer,
#     flag_ocorrencia_30d integer,
#     flag_ocorrencia_60d integer,
#     data_nascimento_pessoa date,
#     data_ultima_prisao date,
#     nome_mae varchar(90),
#     nome_pai varchar(98),
#     etnia char(9))
#                         STORED AS PARQUET LOCATION '/data_lake/gold/intlpris/df_pessoa_final_familiar'
#
# DROP TABLE gold.df_pessoa_final_familiar
# Estatísticas atualizadas para gold.df_pessoa_final_familiar
# Tabela enviada com sucesso para o PostgreSQL: sinp.df_pessoa_final_familiar
# PK definida: id_pessoa
# +-------------+----------------+
# |total_pessoas|total_visitantes|
# +-------------+----------------+
# |278902       |151759          |
# +-------------+----------------+
#
# CREATE EXTERNAL TABLE gold.tmp_base_visitareligiosa
#                         (id_visitante_religioso_origem char(5),
#     nome_pessoa varchar(75),
#     instituicao varchar(106),
#     documento_original varchar(20),
#     presidio_id_origem char(2),
#     documento_digitos char(13),
#     cpf_normalizado char(11),
#     documento_normalizado varchar(17),
#     chave_documento varchar(19))
#                         STORED AS PARQUET LOCATION '/data_lake/gold/intlpris/tmp_base_visitareligiosa'
#
# DROP TABLE gold.tmp_base_visitareligiosa
# Estatísticas atualizadas para gold.tmp_base_visitareligiosa
# CREATE EXTERNAL TABLE gold.tmp_base_visitareligiosa_rank
#                         (id_visitante_religioso_origem char(5),
#     nome_pessoa varchar(75),
#     instituicao varchar(106),
#     documento_original varchar(20),
#     presidio_id_origem char(2),
#     documento_digitos char(13),
#     cpf_normalizado char(11),
#     documento_normalizado varchar(17),
#     chave_documento varchar(19),
#     rn integer)
#                         STORED AS PARQUET LOCATION '/data_lake/gold/intlpris/tmp_base_visitareligiosa_rank'
#
# DROP TABLE gold.tmp_base_visitareligiosa_rank
# Estatísticas atualizadas para gold.tmp_base_visitareligiosa_rank
# CREATE EXTERNAL TABLE gold.tmp_filtrada_visitareligiosa
#                         (id_visitante_religioso_origem char(5),
#     nome_pessoa varchar(75),
#     instituicao varchar(106),
#     documento_original varchar(20),
#     documento_digitos char(13),
#     cpf_normalizado char(11),
#     documento_normalizado char(16),
#     chave_documento varchar(19),
#     presidio_id_origem char(2),
#     documento_formatado varchar(19),
#     cod_documento_referencia integer,
#     desc_documento_referencia char(9))
#                         STORED AS PARQUET LOCATION '/data_lake/gold/intlpris/tmp_filtrada_visitareligiosa'
#
# DROP TABLE gold.tmp_filtrada_visitareligiosa
# Estatísticas atualizadas para gold.tmp_filtrada_visitareligiosa
# CREATE EXTERNAL TABLE gold.tmp_base_pessoa_atual_religiosa
#                         (id_preso char(6),
#     id_pessoa varchar(24),
#     origem char(15),
#     cod_documento_referencia integer,
#     desc_documento_referencia varchar(27),
#     documento varchar(20),
#     nome_pessoa varchar(99),
#     sexo_pessoa varchar(21),
#     flag_presidiario integer,
#     flag_advogado integer,
#     flag_servidor integer,
#     flag_visitante integer,
#     flag_ocorrencia_10d integer,
#     flag_ocorrencia_30d integer,
#     flag_ocorrencia_60d integer,
#     data_nascimento_pessoa date,
#     data_ultima_prisao date,
#     nome_mae varchar(90),
#     nome_pai varchar(98),
#     etnia char(9),
#     documento_digitos varchar(20),
#     chave_documento varchar(24))
#                         STORED AS PARQUET LOCATION '/data_lake/gold/intlpris/tmp_base_pessoa_atual_religiosa'
#
# DROP TABLE gold.tmp_base_pessoa_atual_religiosa
# Estatísticas atualizadas para gold.tmp_base_pessoa_atual_religiosa
# CREATE EXTERNAL TABLE gold.tmp_pessoa_atualizada_religiosa
#                         (id_preso char(6),
#     id_pessoa char(15),
#     origem char(15),
#     cod_documento_referencia integer,
#     desc_documento_referencia varchar(24),
#     documento char(14),
#     nome_pessoa varchar(36),
#     sexo_pessoa char(9),
#     flag_presidiario integer,
#     flag_advogado integer,
#     flag_servidor integer,
#     flag_visitante integer,
#     flag_ocorrencia_10d integer,
#     flag_ocorrencia_30d integer,
#     flag_ocorrencia_60d integer,
#     data_nascimento_pessoa date,
#     data_ultima_prisao date,
#     nome_mae varchar(39),
#     nome_pai varchar(30),
#     etnia char(6))
#                         STORED AS PARQUET LOCATION '/data_lake/gold/intlpris/tmp_pessoa_atualizada_religiosa'
#
# DROP TABLE gold.tmp_pessoa_atualizada_religiosa
# Estatísticas atualizadas para gold.tmp_pessoa_atualizada_religiosa
# CREATE EXTERNAL TABLE gold.tmp_pessoa_mantida_religiosa
#                         (id_preso char(6),
#     id_pessoa varchar(24),
#     origem char(15),
#     cod_documento_referencia integer,
#     desc_documento_referencia varchar(27),
#     documento varchar(20),
#     nome_pessoa varchar(99),
#     sexo_pessoa varchar(21),
#     flag_presidiario integer,
#     flag_advogado integer,
#     flag_servidor integer,
#     flag_visitante integer,
#     flag_ocorrencia_10d integer,
#     flag_ocorrencia_30d integer,
#     flag_ocorrencia_60d integer,
#     data_nascimento_pessoa date,
#     data_ultima_prisao date,
#     nome_mae varchar(90),
#     nome_pai varchar(98),
#     etnia char(9))
#                         STORED AS PARQUET LOCATION '/data_lake/gold/intlpris/tmp_pessoa_mantida_religiosa'
#
# DROP TABLE gold.tmp_pessoa_mantida_religiosa
# Estatísticas atualizadas para gold.tmp_pessoa_mantida_religiosa
# CREATE EXTERNAL TABLE gold.tmp_pessoa_nova_religiosa
#                         (id_preso char(1),
#     id_pessoa varchar(19),
#     origem char(16),
#     cod_documento_referencia integer,
#     desc_documento_referencia char(9),
#     documento varchar(19),
#     nome_pessoa varchar(75),
#     sexo_pessoa char(1),
#     flag_presidiario integer,
#     flag_advogado integer,
#     flag_servidor integer,
#     flag_visitante integer,
#     flag_ocorrencia_10d integer,
#     flag_ocorrencia_30d integer,
#     flag_ocorrencia_60d integer,
#     data_nascimento_pessoa date,
#     data_ultima_prisao date,
#     nome_mae char(1),
#     nome_pai char(1),
#     etnia char(1))
#                         STORED AS PARQUET LOCATION '/data_lake/gold/intlpris/tmp_pessoa_nova_religiosa'
#
# DROP TABLE gold.tmp_pessoa_nova_religiosa
# Estatísticas atualizadas para gold.tmp_pessoa_nova_religiosa
# CREATE EXTERNAL TABLE gold.sinp_ent_pessoa
#                         (id_preso char(6),
#     id_pessoa varchar(24),
#     origem char(16),
#     cod_documento_referencia integer,
#     desc_documento_referencia varchar(27),
#     documento varchar(20),
#     nome_pessoa varchar(99),
#     sexo_pessoa varchar(21),
#     flag_presidiario integer,
#     flag_advogado integer,
#     flag_servidor integer,
#     flag_visitante integer,
#     flag_ocorrencia_10d integer,
#     flag_ocorrencia_30d integer,
#     flag_ocorrencia_60d integer,
#     data_nascimento_pessoa date,
#     data_ultima_prisao date,
#     nome_mae varchar(90),
#     nome_pai varchar(98),
#     etnia char(9))
#                         STORED AS PARQUET LOCATION '/data_lake/gold/intlpris/sinp_ent_pessoa'
#
# DROP TABLE gold.sinp_ent_pessoa
# Estatísticas atualizadas para gold.sinp_ent_pessoa
# CREATE EXTERNAL TABLE gold.tmp_pg_sinp_ent_pessoa
#                         (id_preso char(6),
#     id_pessoa varchar(30),
#     origem char(16),
#     cod_documento_referencia integer,
#     desc_documento_referencia varchar(27),
#     documento varchar(20),
#     nome_pessoa varchar(99),
#     sexo_pessoa varchar(21),
#     flag_presidiario integer,
#     flag_advogado integer,
#     flag_servidor integer,
#     flag_visitante integer,
#     flag_ocorrencia_10d integer,
#     flag_ocorrencia_30d integer,
#     flag_ocorrencia_60d integer,
#     data_nascimento_pessoa date,
#     data_ultima_prisao date,
#     nome_mae varchar(90),
#     nome_pai varchar(98),
#     etnia char(9))
#                         STORED AS PARQUET LOCATION '/data_lake/gold/intlpris/tmp_pg_sinp_ent_pessoa'
#
# DROP TABLE gold.tmp_pg_sinp_ent_pessoa
# Estatísticas atualizadas para gold.tmp_pg_sinp_ent_pessoa
# Tabela enviada com sucesso para o PostgreSQL: sinp.tmp_pg_sinp_ent_pessoa
# PK definida: id_pessoa
